# %% [markdown]
# <a href="https://colab.research.google.com/github/bitmorphic/nocap-deepfake/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
