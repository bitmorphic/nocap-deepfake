# %% [markdown]
# <a href="https://colab.research.google.com/github/bitmorphic/nocap-deepfake/blob/main/notebooks/Week1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NoCap — Deepfake Video Detector
# ## Week 1 — Project Setup
#
# Team Quad Logic - NIT Delhi
#
# - Mount Google Drive and create project folder structure
# - Connect GitHub repository
# - Install all required libraries
# - Verify GPU is available
# - Save config file to Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os

# Create complete project structure
BASE = '/content/drive/MyDrive/NoCap-Deepfake'

folders = [
    f'{BASE}',
    f'{BASE}/models/checkpoints',
    f'{BASE}/outputs/gradcam',
    f'{BASE}/outputs/plots',
    f'{BASE}/outputs/results',
    f'{BASE}/data',
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')

print('\n All folders created')
print(f'Base: {BASE}')
# Out:
# Mounted at /content/drive
# Created: /content/drive/MyDrive/NoCap-Deepfake
# Created: /content/drive/MyDrive/NoCap-Deepfake/models/checkpoints
# Created: /content/drive/MyDrive/NoCap-Deepfake/outputs/gradcam
# Created: /content/drive/MyDrive/NoCap-Deepfake/outputs/plots
# Created: /content/drive/MyDrive/NoCap-Deepfake/outputs/results
# Created: /content/drive/MyDrive/NoCap-Deepfake/data
#
#  All folders created
# Base: /content/drive/MyDrive/NoCap-Deepfake

# %%
# Install all required libraries
# !pip install -q efficientnet-pytorch facenet-pytorch albumentations opencv-python-headless scikit-learn matplotlib seaborn

import torch
import torchvision
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import sklearn
import albumentations

print('torch:', torch.__version__)
print('torchvision:', torchvision.__version__)
print('cv2:', cv2.__version__)
print('numpy:', np.__version__)
print('sklearn:', sklearn.__version__)
print('albumentations:', albumentations.__version__)

# Check GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'\n Device: {device}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
else:
    print('No GPU — switch to T4 in Runtime settings')
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 105.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 122.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 107.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 79.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...

# %%
import torch
import torchvision
import cv2
import numpy as np
from PIL import Image
import sklearn

print('torch:', torch.__version__)
print('torchvision:', torchvision.__version__)
print('cv2:', cv2.__version__)
print('numpy:', np.__version__)
print('PIL:', Image.__version__)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'\n Device: {device}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
else:
    print('No GPU — switch to T4')
# Out:
# torch: 2.10.0+cu128
# torchvision: 0.25.0+cu128
# cv2: 4.13.0
# numpy: 2.0.2
# PIL: 11.3.0
#
#  Device: cuda
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, json

# Kaggle credentials
os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump({
        "username": "mohammadanas06",
        "key": "KGAT_93eeaf2618ca28a97dd21099844a4abe"
    }, f)
os.chmod('/root/.kaggle/kaggle.json', 0o600)
print('Kaggle credentials set')

# Create Drive folder structure
BASE = '/content/drive/MyDrive/NoCap-Deepfake'
folders = [
    f'{BASE}',
    f'{BASE}/models/checkpoints',
    f'{BASE}/outputs/gradcam',
    f'{BASE}/outputs/plots',
    f'{BASE}/outputs/results',
    f'{BASE}/data',
    f'{BASE}/notebooks',
]
for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f' {folder}')

print('\n Drive structure created!')
# Out:
# Mounted at /content/drive
# Kaggle credentials set
#  /content/drive/MyDrive/NoCap-Deepfake
#  /content/drive/MyDrive/NoCap-Deepfake/models/checkpoints
#  /content/drive/MyDrive/NoCap-Deepfake/outputs/gradcam
#  /content/drive/MyDrive/NoCap-Deepfake/outputs/plots
#  /content/drive/MyDrive/NoCap-Deepfake/outputs/results
#  /content/drive/MyDrive/NoCap-Deepfake/data
#  /content/drive/MyDrive/NoCap-Deepfake/notebooks
#
#  Drive structure created!

# %%
# Save project config to Drive
config = """
# NoCap — Deepfake Detector Config
BASE_DIR = '/content/drive/MyDrive/NoCap-Deepfake'
MODEL_DIR = f'{BASE_DIR}/models/checkpoints'
OUTPUT_DIR = f'{BASE_DIR}/outputs'
DATA_DIR = '/content/dfdc'

# Model
MODEL_NAME = 'efficientnet-b4'
NUM_CLASSES = 1
IMAGE_SIZE = 224
BATCH_SIZE = 32
NUM_EPOCHS = 5
LEARNING_RATE = 1e-4

# Dataset
SEQ_LEN = 20
TRAIN_SPLIT = 'train'
VAL_SPLIT = 'validation'

# Device
import torch
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
"""

import os
BASE = '/content/drive/MyDrive/NoCap-Deepfake'
with open(f'{BASE}/config.py', 'w') as f:
    f.write(config)

print('Config saved to Drive!')
print(f'Location: {BASE}/config.py')
# Out:
# Config saved to Drive!
# Location: /content/drive/MyDrive/NoCap-Deepfake/config.py

# %%
import torch
import os

BASE = '/content/drive/MyDrive/NoCap-Deepfake'

print('='*50)
print('NoCap - Week 1 Setup Summary')
print('='*50)

# Check GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'\n Device   : {device}')
if torch.cuda.is_available():
    print(f'GPU      : {torch.cuda.get_device_name(0)}')
    print(f'VRAM     : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')

# Check Drive folders
print('\n Drive Structure:')
for root, dirs, files in os.walk(BASE):
    level = root.replace(BASE, '').count(os.sep)
    indent = '   ' * level
    print(f'{indent} FOLDER {os.path.basename(root)}/')

# Check config
config_path = f'{BASE}/config.py'
print(f'\n Config file: {" Found" if os.path.exists(config_path) else "Missing"}')

# Check libraries
libs = ['torch', 'torchvision', 'cv2', 'PIL', 'sklearn', 'albumentations']
print('\n Libraries:')
for lib in libs:
    try:
        __import__(lib)
        print(f' FOUND {lib}')
    except:
        print(f'{lib} — missing!')

print('\n' + '='*50)
print('Week 1 Complete! Ready for Week 2!')
print('='*50)
# Out:
# ...
# NoCap - Week 1 Setup Summary
# ...
#
#  Device   : cuda
# GPU      : Tesla T4
# VRAM     : 15.6 GB
#
#  Drive Structure:
#  FOLDER NoCap-Deepfake/
#     FOLDER models/
#        FOLDER checkpoints/
#     FOLDER outputs/
#        FOLDER gradcam/
#        FOLDER plots/
#        FOLDER results/
#     FOLDER data/
#     FOLDER notebooks/
#
#  Config file:  Found
#
#  Libraries:
#  FOUND torch
#  FOUND torchvision
#  FOUND cv2
#  FOUND PIL
#  FOUND sklearn
#  FOUND albumentations
#
# ...
# Week 1 Complete! Ready for Week 2!
# ...
